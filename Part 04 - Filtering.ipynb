# %% [markdown]
# <p><li>filt = (df["last"] == "Doe") <font color="red">&</font> (df["first"] == "John") - filt = (df["last"] == "Doe") <font color="red">|</font> (df["first"] == "John")</li></p>
# <p><li>df.loc[<font color="red">~</font>filt, "email"]</li></p>
# <p><li>df[filt] - df.loc[filt]</li></p>
# <p><li>high_salary = (df["ConvertedComp"] > 7000) - df.loc[high_salary, ["Country", "LanguageWorkedWith", "ConvertedComp"]]</li></p>
# <p><li>countries = ["United States", "India", "United Kingdom", "Germany", "Canada"] - filt = df['Country'].<font color="red">isin</font>(countries) - df.loc[filt]</li></p>
# <p><li>filt = df['LanguageWorkedWith'].<font color="red">str.contains</font>("Python", <font color="red">na=False</font>) ,- df.loc[filt, 'LanguageWorkedWith']</p>

# %%
import pandas as pd

# %%
people = {
    "first": ["Corey", "Jane", "John"],
    "last": ["Schafer", "Doe", "Doe"],
    "email": ["CoreyMSchafer@gmail.com", "JaneDoe@email.com", "JohnDoe@email.com" ]
}

# %%
df = pd.DataFrame(people)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df["last"] == "Doe"
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %%
filt = (df["last"] == "Doe")
df[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com
# 2  John  Doe  JohnDoe@email.com

# %%
df.loc[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com
# 2  John  Doe  JohnDoe@email.com

# %%
df.loc[filt, "email"]
# Out:
# 1    JaneDoe@email.com
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %%
filt = (df["last"] == "Doe") & (df["first"] == "John")
df.loc[filt, "email"]
# Out:
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %%
filt = (df["last"] == "Doe") | (df["first"] == "John")
df.loc[filt, "email"]
# Out:
# 1    JaneDoe@email.com
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %%
filt = (df["last"] == "Schafer") | (df["first"] == "John")
df.loc[~filt, "email"]
# Out:
# 1    JaneDoe@email.com
# Name: email, dtype: object

# %%
df = pd.read_csv("datas/survey_results_public.csv", index_col="Respondent")
schema_df = pd.read_csv("datas/survey_results_schema.csv", index_col="Column")

pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
high_salary = (df["ConvertedComp"] > 7000)
df.loc[high_salary, ["Country", "LanguageWorkedWith", "ConvertedComp"]]
# Out:
#                   Country                                 LanguageWorkedWith  \
# Respondent
# 3                Thailand                                           HTML/CSS
# 4           United States                                C;C++;C#;Python;SQL
# 6                  Canada                                         Java;R;SQL
# 9             New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 10                  India                      C#;Go;JavaScript;Python;R;SQL
# ...                   ...                                                ...
# 88878       United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879             Finland                   Bash/Shell/PowerShell;C++;Python
# 88881             Austria  Bash/Shell/PowerShell;Go;HTML/CSS;Java;JavaScr...
# 88882         Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
# 88883              Greece              Go;HTML/CSS;Java;JavaScript;Other(s):
#
#             ConvertedComp
# ...

# %%
countries = ["United States", "India", "United Kingdom", "Germany", "Canada"]
filt = df['Country'].isin(countries)
df.loc[filt]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 4                              I am a developer by profession       No
# 6           I am not primarily a developer, but I write co...      Yes
# 8                                 I code primarily as a hobby      Yes
# 10                             I am a developer by profession      Yes
# ...                                                       ...      ...
# 85642                                                     NaN       No
# 85961                                                     NaN      Yes
# 86012                                                     NaN      Yes
# 88282                                                     NaN      Yes
# 88377                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
filt = df['LanguageWorkedWith'].str.contains("Python", na=False)
df.loc[filt, 'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object
